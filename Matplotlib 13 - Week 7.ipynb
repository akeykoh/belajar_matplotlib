# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)
#
# # BIC02 - Visualisasi Data
#
# Nama: Angelique Keyko Haryono
#
# NRP: 2073016

# %% [markdown]
# ### Week 7 - 3D Plot
#
# 1. Cara Import Module dan Mengecek Version
# 2. 3D Axes
# 3. 3D Line Plot

# %% [markdown]
# #### Cara Import Module dan Mengecek Version
#
# Disini kita akan mengaktifkan magic comment yaitu `%matplotlib notebook`. Sebenarnya magic comment ini mirip dengan `%matplotlib inline` yaitu untuk memastikan output yang dihasilkan matplotlib bisa tampil di halaman Jupyter Notebook. Yang berbeda adalah dengan `%matplotlib notebook`, kita bisa berinteraksi dengan 3D plotting yang dihasilkan.

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
#Ini merupakan cara untuk mengimport module.
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#Ini merupakan cara mengecek version module.
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# #### 3D Axes
#
# Untuk 3D axes, kita harus membangun sendiri object figure dan axesnya. Axes yang akan kita bentuk adalah axes untuk 3 dimensi, caranya adalah menyertakan parameter projection dengan nilai 3d.

# %%
fig = plt.figure() # membentuk object figure
ax = plt.axes(projection='3d') # membentuk object axes

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# #### 3D Line Plot
#
# Kita akan mecoba melakukan plotting untuk 3 variabel pada area 3 dimensi. Caranya adalah:
# - Tentukan 3 variabel dan isi datanya untuk di plotting.
# - Membentuk object figure dengan method `plt.figure()`.
# - Membentuk object 3D axes dengan method `plt.axes(projection='3d')`.
# - Melakukan plotting berupa line plot dengan memanggil `ax.plot`.
# - Melakukan pengaturan label dengan `ax.set`.
# - Melihat hasil 3Dline plot dengan `plt.show()`

# %%
# 3 variabel yang akan di plotting pada area 3 dimensi.
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z) 
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x, y, z, color='red') # color untuk mengatur warna line plot

ax.set(title='Contoh 3D Line Plot',
       xlabel = 'Sumbu X',
       ylabel = 'Sumbu Y',
       zlabel = 'Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
