# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)
#
# # BIC02 - Visualisasi Data
#
# Nama: Angelique Keyko Haryono
#
# NRP: 2073016

# %% [markdown]
# ### Week 10 - Pengaturan Figure Layout dengan GridSpec
#
# 1. Cara Import Module dan Mengecek Version
# 2. Simple 2x2 Layout dengan Subplots

# %% [markdown]
# #### Cara Import Module dan Mengecek Version
#
# Sebelum mengimport module, kita bisa menjalankan magic comment. `%matplotlib inline` dikenal sebagai magic comment pada Jupyter Notebook dan Jupyter Lab. Kegunaannya adalah untuk memastikan setiap output dari matplotlib akan ditampilkan dalam halaman notebook yang sama. Magic comment ini harus kita eksekusi, terutama jika kita menggunakan Jupyter Notebook versi lama. Sedangkan untuk Jupyter Notebook versi lebih baru, tidak diperlukan karena secara default jika kita melakukan plotting dengan matplotlib, maka hasilnya akan secara otomatis ditampilkan pada notebook.

# %%
# %matplotlib inline

# %%
#Ini merupakan cara untuk mengimport module.
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

#Ini merupakan cara mengecek version module.
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# #### Simple 2x2 Layout dengan Subplots
#
# Kita bisa melakukan plotting sederhana dengan menggunakan layout 2x2 dan memanfaatkan subplots. Langkah-langkahnya adalah:
# - Menyiapkan data set, Disini kita membuat 2 variabel yaitu siswa dan uas.
# - Membentuk figure dan axes dengan memanggil method `plt.subplots` dan menyertakan beberapa parameter yaitu `ncols=2`, `nrows=2`, dan `constrained_layout=True`. Parameter constrained_layout kita beri nilai True agar tampilan ouput tidak terlalu rapat dan tidak ada yang tertimpa satu sama lain.
# - Mengakses object axes dengan cara menggunakan `axes[index_baris][index_kolom]`.
# - Menunjukkan hasil plotting dengan method `plt.show()`.

# %%
# Menyiapkan data set.
siswa = ['Cecep', 'Joko', 'Wati', 'Ani'] # nama siswa
uas = [68, 83, 96, 72]                   # nilai uas siswa

# Membentuk figure dan axes.
fig, axes = plt.subplots(ncols=2, nrows=2, constrained_layout=True)

# Proses plotting.
axes[0][0].bar(siswa, uas)                               #mengakses object axes pada baris 0 dan kolom 0.
axes[0][1].pie(uas, labels=siswa)                        #mengakses object axes pada baris 0 dan kolom 1.
axes[1][0].pie(uas, labels=siswa,explode=[0, 0, 0, 0.2]) #mengakses object axes pada baris 1 dan kolom 0.
axes[1][1].barh(siswa, uas)                              #mengakses object axes pada baris 1 dan kolom 1.

# Menunjukkan hasil plotting
plt.show()
