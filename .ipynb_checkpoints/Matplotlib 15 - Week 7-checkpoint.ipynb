# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)
#
# # BIC02 - Visualisasi Data
#
# Nama: Angelique Keyko Haryono
#
# NRP: 2073016

# %% [markdown]
# ### Week 7 - 3D Area Plotting
#
# 1. Cara Import Module dan Mengecek Version
# 2. Sample Datase
# 3. 3D Wireframe
# 4. 3D Surface Plot

# %% [markdown]
# #### Cara Import Module dan Mengecek Version
#
# Disini kita akan mengaktifkan magic comment yaitu `%matplotlib notebook`. Sebenarnya magic comment ini mirip dengan `%matplotlib inline` yaitu untuk memastikan output yang dihasilkan matplotlib bisa tampil di halaman Jupyter Notebook. Yang berbeda adalah dengan `%matplotlib notebook`, kita bisa berinteraksi dengan 3D plotting yang dihasilkan.

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
#Ini merupakan cara untuk mengimport module.
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#Ini merupakan cara mengecek version module.
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# #### Sample Dataset
#
# Kita akan menyiapkan sample dataset yang terdiri dari deret bilangan dengan nilai min -3 dan nilai max 3, total data point yang dihasilkan adalah 100 data point. Untuk membentuk data surface / area, kita bisa menggunakan method `np.meshgrid()`.

# %%
n = np.linspace(-3.0, 3.0, 100)

x,y = np.meshgrid(n, n)  # menghasilkan data 2 dimensi yang ditampung pada variabel x dan y.
z = np.sqrt(x**2 + y**2) # menampung hasil akar kuadrat dari penjumlahan x kuadran dan y kuadrat.

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# #### 3D Wireframe
#
# Langkah-langkah untuk menghasilkan 3D wireframe:
# - Membentuk object figure dengan method `plt.figure()`.
# - Membentuk object 3D axes dengan method `plt.axes(projection='3d')`.
# - Melakukan plotting data dengan method `.plot_wireframe`. Method ini membutuhkan setidaknya 3 parameter. Parameter 1 berkolerasi dengan nilai koordinat x. Parameter 2 berkolerasi dengan nilai koordinat y. Parameter 3 berkolerasi dengan nilai koordinat z. Parameter 4 yaitu color (optional) untuk mengatur warna hasil plotting.
# - Melakukan pengaturan label dengan `ax.set`.
# - Melihat hasil 3Dline plot dengan `plt.show()`

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x, y, z, color='orange') # color untuk mengatur warna line plot

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="978.6666666666666">

# %% [markdown]
# #### 3D Surface Plot
#
# Langkah-langkah untuk menghasilkan 3D surface plot:
# - Membentuk object figure dengan method `plt.figure()`.
# - Membentuk object 3D axes dengan method `plt.axes(projection='3d')`.
# - Melakukan plotting data surface plot dengan method `.plot_surface`. Method ini membutuhkan setidaknya 3 parameter. Parameter 1 berkolerasi dengan nilai koordinat x. Parameter 2 berkolerasi dengan nilai koordinat y. Parameter 3 berkolerasi dengan nilai koordinat z. Parameter 4 yaitu color (optional) untuk mengatur warna hasil plotting. Selain color, kita bisa memanfaatkan paramater cmap.
# - Melakukan pengaturan label dengan `ax.set`.
# - Melihat hasil 3Dline plot dengan `plt.show()`

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, color='orange') # color untuk mengatur warna line plot
# ax.plot_surface(x, y, z, cmap='viridis') # memanfaatkan color map.

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="985.3333333333334">
